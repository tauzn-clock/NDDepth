# %%
import sys
sys.path.append('/NDDepth/src')

from dataloader.BaseDataloader import BaseImageData, BaseImageDataset
from dataloader.NYUDataloader import NYUImageData
from torch.utils.data import DataLoader

# %%
train_dataset = BaseImageDataset('train', NYUImageData, '/scratchdata/nyu_data', '/scratchdata/nyu_data/data/nyu2_train.csv')
train_dataloader = DataLoader(train_dataset, batch_size=2, pin_memory=True)

# %%
cnt = 0
for i, x in enumerate(train_dataloader):
    cnt += 1
    if cnt==10: break
    print(i)
    print(x["pixel_values"].shape)
# Out:
# 0
# torch.Size([2, 3, 480, 640])
# 1
# torch.Size([2, 3, 480, 640])
# 2
# torch.Size([2, 3, 480, 640])
# 3
# torch.Size([2, 3, 480, 640])
# 4
# torch.Size([2, 3, 480, 640])
# 5
# torch.Size([2, 3, 480, 640])
# 6
# torch.Size([2, 3, 480, 640])
# 7
# torch.Size([2, 3, 480, 640])
# 8
# torch.Size([2, 3, 480, 640])

# %%
import matplotlib.pyplot as plt

img = x["pixel_values"][0].permute(1,2,0)

plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..1.8208281].

# %%
depth = x["depth_values"][0].permute(1,2,0)

plt.imshow(depth)

# %%
mask = x["mask"][0].permute(1,2,0)
plt.imshow(img)
plt.imshow(mask, alpha=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..1.8208281].
